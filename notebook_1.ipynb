# %% [markdown]
# <a href="https://colab.research.google.com/github/davneesh/ds_Avneesh_Dayal/blob/main/notebook_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
historical_data = pd.read_csv('/content/drive/MyDrive/Data Science Assignment Instructions - Web3 Trading Team/csv_files/historical_data.csv')
fear_greed_index = pd.read_csv('/content/drive/MyDrive/Data Science Assignment Instructions - Web3 Trading Team/csv_files/fear_greed_index.csv')

# %%
print(historical_data.shape)
print(fear_greed_index.shape)
# Out:
# (211224, 16)
# (2644, 4)

# %%
historical_data.info()
fear_greed_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
historical_data.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
fear_greed_index.head()
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
historical_data['timestamp_dt'] = pd.to_datetime(historical_data['Timestamp IST'], format="%d-%m-%Y %H:%M")
historical_data['date'] = historical_data['timestamp_dt'].dt.date  # Keep date only

# %%
historical_data['date'] = pd.to_datetime(historical_data['date'], errors='coerce')

fear_greed_index['date'] = pd.to_datetime(fear_greed_index['date'], errors='coerce')

# %%
fear_greed_map = {
    'Fear': 'Fear',
    'Extreme Fear': 'Fear',
    'Greed': 'Greed',
    'Extreme Greed': 'Greed'
}
fear_greed_index['sentiment'] = fear_greed_index['classification'].map(fear_greed_map)

# %%
merged_df = historical_data.merge(fear_greed_index[['date','sentiment', 'value']], on='date', how='left')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
merged_df['is_win'] = merged_df['Closed PnL'] > 0

merged_df['Side'] = merged_df['Side'].str.upper().map({
    'BUY': 'Long',
    'SELL': 'Short'
}).fillna(merged_df['Side'])

merged_df['pnl_per_usd'] = merged_df['Closed PnL'] / merged_df['Size USD']

# %%
print(merged_df[['date', 'sentiment', 'Closed PnL']].head())
print(merged_df['sentiment'].value_counts(dropna=False))
# Out:
#         date sentiment  Closed PnL
# 0 2024-12-02     Greed         0.0
# 1 2024-12-02     Greed         0.0
# 2 2024-12-02     Greed         0.0
# 3 2024-12-02     Greed         0.0
# 4 2024-12-02     Greed         0.0
# sentiment
# Greed    90295
# Fear     83237
# NaN      37692
# Name: count, dtype: int64

# %%
agg_by_sentiment = merged_df.groupby('sentiment').agg(
    trades_count=('Closed PnL','count'),
    avg_pnl=('Closed PnL','mean'),
    median_pnl=('Closed PnL','median'),
    win_rate=('is_win','mean'),
    avg_trade_size_usd=('Size USD','mean')
).reset_index()

print("Performance Summary by Sentiment")
print(agg_by_sentiment)
# Out:
# Performance Summary by Sentiment
#   sentiment  trades_count    avg_pnl  median_pnl  win_rate  avg_trade_size_usd
# 0      Fear         83237  49.212077         0.0  0.407871         7182.011019
# 1     Greed         90295  53.882281         0.0  0.420311         4574.424490

# %%
side_sent = merged_df.groupby(['sentiment','Side'])['Closed PnL'].mean().unstack()
print("Avg PnL by Side × Sentiment")
print(side_sent)
# Out:
# Avg PnL by Side × Sentiment
# Side            Long      Short
# sentiment
# Fear       56.015456  42.542558
# Greed      18.882476  85.026753

# %%
agg_by_sentiment.to_csv('/content/drive/MyDrive/Data Science Assignment Instructions - Web3 Trading Team/csv_files/agg_by_sentiment.csv', index=False)
side_sent.to_csv('/content/drive/MyDrive/Data Science Assignment Instructions - Web3 Trading Team/csv_files/side_sentiment_pnl.csv')
